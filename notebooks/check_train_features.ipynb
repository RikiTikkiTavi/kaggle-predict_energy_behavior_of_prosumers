# %%
import pandas as pd

pd.read_csv("/beegfs/ws/0/s4610340-energy_behavior/yahor/kaggle-predict_energy_behavior_of_prosumers/data/processed/df_train_features.csv")
# Out:
#          county  is_business  product_type   target  is_consumption   row_id  \
# 0             0            0             1    0.713               0        0
# 1             0            0             1   96.590               1        1
# 2             0            0             2    0.000               0        2
# 3             0            0             2   17.314               1        3
# 4             0            0             3    2.904               0        4
# ...         ...          ...           ...      ...             ...      ...
# 2018347      15            1             0  197.233               1  2018347
# 2018348      15            1             1    0.000               0  2018348
# 2018349      15            1             1   28.404               1  2018349
# 2018350      15            1             3    0.000               0  2018350
# 2018351      15            1             3  196.240               1  2018351
#
# ...
